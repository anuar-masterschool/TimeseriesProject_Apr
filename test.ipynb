# %% [markdown]
# # Title: *Test* Notebook

# %%
import pandas as pd

# %%
a=3

# %%
b = 3

# %% [markdown]
# ## Subtitle
# sadfsafs

# %%
d = 5

# %%
print("hello")

# %%
print("sfds")

# %% [markdown]
# ## Subtitle 2

# %%
print(a,b,d)

# %%
print(c)
